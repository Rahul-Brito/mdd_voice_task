# %%
import sub_level_effects_size_calculate
# Out:
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
# /om2/user/rfbrito/miniconda/envs/imaging/lib/python3.11/site-packages/nilearn/glm/first_level/experimental_paradigm.py:89: UserWarning: Unexpected column `nonword` in events data will be ignored.
#   warnings.warn(("Unexpected column `{}` in events "
# 230509-10:23:00,347 nipype.interface INFO:
# 	 Setting dt = 110 ms
#
# 230509-10:23:00,349 nipype.interface INFO:
# 	 response sum: 1.0000 max: 0.0231
# 230509-10:23:00,349 nipype.interface INFO:
# 	 reg_scale: 43.1973
# 230509-10:23:00,352 nipype.interface INFO:
# 	 Setting dt = 110 ms
#
# 230509-10:23:00,353 nipype.interface INFO:
# 	 response sum: 1.0000 max: 0.0231
# 230509-10:23:00,354 nipype.interface INFO:
# 	 reg_scale: 43.1973
# 230509-10:23:00,357 nipype.interface INFO:
# 	 Setting dt = 110 ms
#
# 230509-10:23:00,358 nipype.interface INFO:
# 	 response sum: 1.0000 max: 0.0231
# 230509-10:23:00,358 nipype.interface INFO:
# 	 reg_scale: 43.1973
# ...

# %%
import pandas as pd

# %%
pd.read_pickle('050923_effect_size_variance_df.pkl')
# Out:
#        sub-voice884_ses-1_task-nwr_run-1  sub-voice884_ses-1_task-nwr_run-3  \
# 0                             973.370547                        1396.594872
# 1                             303.581573                        1367.495897
# 2                             790.903031                         617.729096
# 3                             361.603160                         367.965184
# 4                             805.746274                        1012.474850
# ...                                  ...                                ...
# 91277                         404.455443                        1001.340493
# 91278                        2745.250855                        3831.554028
# 91279                        1524.219403                        2358.044496
# 91280                         445.631555                        1194.172672
# 91281                         327.182655                         918.798958
#
#        sub-voice884_ses-1_task-pataka_run-2  \
# ...
