# %%
import first_level_glm_all_sub
# Out:
# 231025-16:08:20,141 nipype.interface INFO:
# 	 Setting dt = 64 ms
#
# 231025-16:08:20,144 nipype.interface INFO:
# 	 response sum: 1.0000 max: 0.0135
# 231025-16:08:20,145 nipype.interface INFO:
# 	 reg_scale: 74.2276
# 231025-16:08:20,151 nipype.interface INFO:
# 	 Setting dt = 64 ms
#
# 231025-16:08:20,153 nipype.interface INFO:
# 	 response sum: 1.0000 max: 0.0135
# 231025-16:08:20,154 nipype.interface INFO:
# 	 reg_scale: 74.2276
# 231025-16:08:20,160 nipype.interface INFO:
# 	 Setting dt = 64 ms
#
# 231025-16:08:20,161 nipype.interface INFO:
# 	 response sum: 1.0000 max: 0.0135
# 231025-16:08:20,162 nipype.interface INFO:
# 	 reg_scale: 74.2276
# 231025-16:08:20,168 nipype.interface INFO:
# 	 Setting dt = 64 ms
#
# 231025-16:08:20,169 nipype.interface INFO:
# 	 response sum: 1.0000 max: 0.0135
# 231025-16:08:20,170 nipype.interface INFO:
# 	 reg_scale: 74.2276
# 231025-16:08:25,880 nipype.interface INFO:
# 	 Setting dt = 110 ms
#
# 231025-16:08:25,882 nipype.interface INFO:
# ...
