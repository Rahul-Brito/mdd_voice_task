# %%
import pandas as pd

# %%
##initially named the columns with the z-scores after glm convolution in an order that does not work well with bids
#fixing it here one time

# %%
#name = "vowel_cifti_zscore.pkl"
#name = "emosent_cifti_zscore.pkl"
#name = "pataka_cifti_zscore.pkl"
#name = "nwr_cifti_zscore.pkl"
#name = "test_vowel_citfi_zscore.pkl"
#name = "test_emosent_citfi_zscore.pkl"
name = "test_pataka_citfi_zscore.pkl"
#name = "test_nwr_citfi_zscore.pkl"

# %%
pop_z_score_df = pd.read_pickle(name)

# %%
pop_z_score_df
# Out:
#        voice884_ses-1_task-pataka_run-2  voice880_ses-1_task-pataka_run-2  \
# 0                             -1.012892                          1.798206
# 1                              1.118503                          1.574351
# 2                              8.899588                         10.189218
# 3                              1.664570                          2.473522
# 4                              0.449620                          2.048848
# ...                                 ...                               ...
# 91277                          2.477419                          2.056352
# 91278                          2.910585                          2.489929
# 91279                          3.914572                          2.330138
# 91280                          2.753118                          1.953667
# 91281                          2.259873                          1.966205
#
#        voice953_ses-1_task-pataka_run-2  voice976_ses-1_task-pataka_run-2  \
# ...

# %%
new_names = []
for c in pop_z_score_df.columns:
    items = c.split('_')
    new_names.append(f'{items[0]}_{items[2]}_{items[3]}_{items[1]}')
pop_z_score_df.columns = new_names
pop_z_score_df.to_pickle(name)

# %%
pop_z_score_df
# Out:
#        voice884_ses-1_task-pataka_run-2  voice880_ses-1_task-pataka_run-2  \
# 0                             -1.012892                          1.798206
# 1                              1.118503                          1.574351
# 2                              8.899588                         10.189218
# 3                              1.664570                          2.473522
# 4                              0.449620                          2.048848
# ...                                 ...                               ...
# 91277                          2.477419                          2.056352
# 91278                          2.910585                          2.489929
# 91279                          3.914572                          2.330138
# 91280                          2.753118                          1.953667
# 91281                          2.259873                          1.966205
#
#        voice953_ses-1_task-pataka_run-2  voice976_ses-1_task-pataka_run-2  \
# ...

# %%
#name = "vowel_cifti_zscore.pkl"
#name = "emosent_cifti_zscore.pkl"
#name = "pataka_cifti_zscore.pkl"
#name = "nwr_cifti_zscore.pkl"
#name = "test_vowel_citfi_zscore.pkl"
#name = "test_emosent_citfi_zscore.pkl"
#name = "test_pataka_citfi_zscore.pkl"
name = "test_nwr_citfi_zscore.pkl"

pop_z_score_df = pd.read_pickle(name)
pop_z_score_df
# Out:
#        voice884_ses-1_task-nwr_run-3  voice884_ses-1_task-nwr_run-2  \
# 0                           1.959787                      -0.692755
# 1                           1.302313                      -0.253504
# 2                           1.984138                       4.024979
# 3                           0.688088                       0.437781
# 4                           1.675564                       0.764403
# ...                              ...                            ...
# 91277                       0.483601                       1.710976
# 91278                       0.915944                       1.908218
# 91279                       0.835594                       2.185403
# 91280                       0.443526                       2.034867
# 91281                       0.163377                       1.846074
#
#        voice857_ses-1_task-nwr_run-3  voice857_ses-1_task-nwr_run-2  \
# 0                           0.145867                      -1.110721
# ...
