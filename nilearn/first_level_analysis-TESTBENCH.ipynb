# %%
import os
import pandas as pd
import numpy as np
import glob
import json
import re
from pathlib import Path

import nibabel 
import nilearn

from nilearn.glm.first_level import FirstLevelModel
from nilearn import image
from nilearn.image import mean_img
from nilearn.plotting import plot_design_matrix
from nilearn.plotting import plot_stat_map, plot_anat, plot_img

from nipype.algorithms import modelgen
from nipype.interfaces.base import Bunch

from bids.layout import parse_file_entities

import matplotlib.pyplot as plt
import tracemalloc
import concurrent.futures

# %%
#task_json_list = glob.glob('../../task*.json')
#task_list = [parse_file_entities(t)['task'] for t in task_json_list]
#task_list

# %%
events_path_pattern = f'/om/project/voice/bids/data/sub-voice*/ses-*/func/*events.tsv'
pop_events = find_populated_events(events_path_pattern)
count_pop_events = pop_events.groupby('task').populated.value_counts()

valid_runs = pop_events.events_file[pop_events.populated == True]
parsed_valid_runs = [parse_file_entities(vr) for vr in valid_runs]

# %%
# test = []
# space='MNI152NLin6Asym'


# for pvr in parsed_valid_runs:
#     sub = pvr['subject']
#     ses = pvr['session']
#     task = pvr['task']
#     run = int(pvr['run'])
#     test.append(glob.glob(f'../../derivatives/fmriprep/sub-{sub}/ses-{ses}/func/sub-{sub}*task-{task}*run-{run}*{space}*preproc*nii.gz')[0])

# %%
type(nifti)

# %%
parsed_valid_runs[0]
# Out:
# {'subject': 'voice884',
#  'session': '1',
#  'task': 'pitchnw',
#  'run': 02,
#  'suffix': 'events',
#  'datatype': 'func',
#  'extension': '.tsv'}

# %%
#single subject tester
# sub = 'voice875'
# task = 'nwr'
# ses = 1
# run = 1

sub='voice884'
ses = 1
task ='nwr'
run = 2

sparse = True

fitted_glm, selected_confounds, nifti, events = run_first_level_model(sub,task,ses,run, sparse = sparse)
show_design_matrix(fitted_glm)
# Out:
# /om2/user/rfbrito/miniconda/envs/voice_img/lib/python3.10/site-packages/nilearn/glm/first_level/experimental_paradigm.py:89: UserWarning: Unexpected column `nonword` in events data will be ignored.
#   warnings.warn(("Unexpected column `{}` in events "

# %%
pd.read_table(events[0])
# Out:
#      onset  duration   trial_type nonword
# 0     0.00       1.1     question  katkit
# 1     1.89       1.1    statement   dudum
# 2     3.89       1.1    statement     nul
# 3     5.89       1.1  exclamation   dudum
# 4     7.89       1.1  exclamation  katkit
# ..     ...       ...          ...     ...
# 95  189.70       1.1  exclamation  katkit
# 96  191.69       1.1     question  katkit
# 97  193.68       1.1     question  katkit
# 98  195.67       1.1  exclamation  katkit
# 99  197.67       1.1     question  katkit
#
# [100 rows x 4 columns]

# %%
#condition 4, iteration 2 causes issue because 

cond
# Out:
# '4'

# %%
plt.plot(timeline2)

# %%
timeline2.shape
# Out:
# (1501,)

# %%
[int(np.round(t / dt)) for i, t in enumerate(onsets)]
# Out:
# [219, 255, 365, 401, 948, 985, 1313, 1350]

# %%
task_json = open(f"../../task-{task}_bold.json")
task_json=json.load(task_json)

TR=task_json['RepetitionTime']
DT=task_json['DelayTime']

sparse_model = modelgen.SpecifySparseModel()
sparse_model.inputs.input_units = 'secs'
sparse_model.inputs.functional_runs = nifti
sparse_model.inputs.time_repetition = TR
sparse_model.inputs.time_acquisition = TR - DT
sparse_model.inputs.high_pass_filter_cutoff = 128.
sparse_model.inputs.model_hrf = True
sparse_model.inputs.subject_info = modelgen.bids_gen_info(events,condition_column='trial_type')  # doctest: +SKIP

infolist = sparse_model.inputs.subject_info

for i, info in enumerate(infolist):
    img = modelgen.load(sparse_model.inputs.functional_runs[i])
    nscans = img.shape[3]
    
    for i, cond in enumerate(info.conditions):
        amplitudes = info.amplitudes[i]
        scaled_onsets = modelgen.scale_timings(
                        info.onsets[i],
                        sparse_model.inputs.input_units,
                        "secs",
                        sparse_model.inputs.time_repetition,
                    )
        scaled_durations = modelgen.scale_timings(
            info.durations[i],
            sparse_model.inputs.input_units,
            "secs",
            sparse_model.inputs.time_repetition,
        )
        
        TR = int(np.round(sparse_model.inputs.time_repetition * 1000))  # in ms
        TA = int(np.round(sparse_model.inputs.time_acquisition * 1000)) 

        nvol = sparse_model.inputs.volumes_in_cluster

        dt = TA / 10.0

        SCANONSET = np.round(sparse_model.inputs.scan_onset * 1000)
        total_time = TR * (nscans - nvol) / nvol + TA * nvol + SCANONSET

        npts = int(np.ceil(total_time / dt))
        timeline2 = np.zeros((npts))

        i_amplitudes = amplitudes

        onsets = np.round(np.array(scaled_onsets) * 1000)

        len(timeline2)

        for i, t in enumerate(onsets):
            idx = int(np.round(t / dt))
            if i_amplitudes:
                if len(i_amplitudes) > 1:
                    timeline2[idx] = i_amplitudes[i]

        #sparse_model._gen_regress(
        #            scaled_onsets, scaled_durations, amplitudes, nscans
        #        )

# %%
sparse_model._cond_to_regress(info, nscans)
# Out:
# 230221-16:59:34,489 nipype.interface INFO:
# 	 Setting dt = 110 ms
#
# 230221-16:59:34,494 nipype.interface INFO:
# 	 response sum: 1.0000 max: 0.0231
# 230221-16:59:34,496 nipype.interface INFO:
# 	 reg_scale: 43.1973
# 230221-16:59:34,504 nipype.interface INFO:
# 	 Setting dt = 110 ms
#
# 230221-16:59:34,508 nipype.interface INFO:
# 	 response sum: 1.0000 max: 0.0231
# 230221-16:59:34,510 nipype.interface INFO:
# 	 reg_scale: 43.1973
# 230221-16:59:34,516 nipype.interface INFO:
# 	 Setting dt = 110 ms
#
# 230221-16:59:34,519 nipype.interface INFO:
# 	 response sum: 1.0000 max: 0.0231
# 230221-16:59:34,520 nipype.interface INFO:
# 	 reg_scale: 43.1973
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 sparse_model._cond_to_regress(info, nscans)
#
# File /om2/user/rfbrito/miniconda/envs/voice_img/lib/python3.10/site-packages/nipype/algorithms/modelgen.py:922, in SpecifySparseModel._cond_to_regress(self, info, nscans)
#     910 scaled_onsets = scale_timings(
#     911     info.onsets[i],
#     912     self.inputs.input_units,
#     913     "secs",
#     914     self.inputs.time_repetition,
#     915 )
#     916 scaled_durations = scale_timings(
#     917     info.durations[i],
#     918     self.inputs.input_units,
#     919     "secs",
#     920     self.inputs.time_repetition,
#     921 )
# --> 922 regressor = self._gen_regress(
#     923     scaled_onsets, scaled_durations, amplitudes, nscans
#     924 )
#     925 if (
#     926     isdefined(self.inputs.use_temporal_deriv)
#     927     and self.inputs.use_temporal_deriv
#     928 ):
#     929     reg.insert(len(reg), regressor[0])
#
# File /om2/user/rfbrito/miniconda/envs/voice_img/lib/python3.10/site-packages/nipype/algorithms/modelgen.py:829, in SpecifySparseModel._gen_regress(self, i_onsets, i_durations, i_amplitudes, nscans)
#     827 if i_amplitudes:
#     828     if len(i_amplitudes) > 1:
# --> 829         timeline2[idx] = i_amplitudes[i]
#     830     else:
#     831         timeline2[idx] = i_amplitudes[0]
#
# IndexError: index 1423 is out of bounds for axis 0 with size 1392

# %%
task_json = open(f"../../task-{task}_bold.json")
task_json=json.load(task_json)

TR=task_json['RepetitionTime']
DT=task_json['DelayTime']

sparse_model = modelgen.SpecifySparseModel()
sparse_model.inputs.input_units = 'secs'
sparse_model.inputs.functional_runs = nifti
sparse_model.inputs.time_repetition = TR
sparse_model.inputs.time_acquisition = TR - DT
sparse_model.inputs.high_pass_filter_cutoff = 128.
sparse_model.inputs.model_hrf = True
sparse_model.inputs.subject_info = modelgen.bids_gen_info(events,condition_column='trial_type')  # doctest: +SKIP

#Is this what I am supposed to do?
#sparse_model.inputs.bids_event_file = events

regressors = sparse_model._list_outputs()['session_info'][0]['regress']
#regressors
# Out:
# 230221-16:43:49,376 nipype.interface INFO:
# 	 Setting dt = 110 ms
#
# 230221-16:43:49,379 nipype.interface INFO:
# 	 response sum: 1.0000 max: 0.0231
# 230221-16:43:49,380 nipype.interface INFO:
# 	 reg_scale: 43.1973
# 230221-16:43:49,387 nipype.interface INFO:
# 	 Setting dt = 110 ms
#
# 230221-16:43:49,391 nipype.interface INFO:
# 	 response sum: 1.0000 max: 0.0231
# 230221-16:43:49,393 nipype.interface INFO:
# 	 reg_scale: 43.1973
# 230221-16:43:49,399 nipype.interface INFO:
# 	 Setting dt = 110 ms
#
# 230221-16:43:49,402 nipype.interface INFO:
# 	 response sum: 1.0000 max: 0.0231
# 230221-16:43:49,403 nipype.interface INFO:
# 	 reg_scale: 43.1973
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[58], line 19
#      14 sparse_model.inputs.subject_info = modelgen.bids_gen_info(events,condition_column='trial_type')  # doctest: +SKIP
#      16 #Is this what I am supposed to do?
#      17 #sparse_model.inputs.bids_event_file = events
# ---> 19 regressors = sparse_model._list_outputs()['session_info'][0]['regress']
#
# File /om2/user/rfbrito/miniconda/envs/voice_img/lib/python3.10/site-packages/nipype/algorithms/modelgen.py:985, in SpecifySparseModel._list_outputs(self)
#     983 outputs = self._outputs().get()
#     984 if not hasattr(self, "_sessinfo"):
# --> 985     self._generate_design()
#     986 outputs["session_info"] = self._sessinfo
#     988 if isdefined(self.inputs.save_plot) and self.inputs.save_plot:
#
# File /om2/user/rfbrito/miniconda/envs/voice_img/lib/python3.10/site-packages/nipype/algorithms/modelgen.py:979, in SpecifySparseModel._generate_design(self, infolist)
#     977 else:
#     978     infolist = gen_info(self.inputs.event_files)
# --> 979 sparselist = self._generate_clustered_design(infolist)
#     980 super(SpecifySparseModel, self)._generate_design(infolist=sparselist)
#
# File /om2/user/rfbrito/miniconda/envs/voice_img/lib/python3.10/site-packages/nipype/algorithms/modelgen.py:958, in SpecifySparseModel._generate_clustered_design(self, infolist)
#     956 img = load(self.inputs.functional_runs[i])
#     957 nscans = img.shape[3]
# --> 958 reg, regnames = self._cond_to_regress(info, nscans)
#     959 if hasattr(infoout[i], "regressors") and infoout[i].regressors:
#     960     if not infoout[i].regressor_names:
#
# File /om2/user/rfbrito/miniconda/envs/voice_img/lib/python3.10/site-packages/nipype/algorithms/modelgen.py:922, in SpecifySparseModel._cond_to_regress(self, info, nscans)
#     910 scaled_onsets = scale_timings(
#     911     info.onsets[i],
#     912     self.inputs.input_units,
#     913     "secs",
#     914     self.inputs.time_repetition,
#     915 )
#     916 scaled_durations = scale_timings(
#     917     info.durations[i],
#     918     self.inputs.input_units,
#     919     "secs",
#     920     self.inputs.time_repetition,
#     921 )
# --> 922 regressor = self._gen_regress(
#     923     scaled_onsets, scaled_durations, amplitudes, nscans
#     924 )
#     925 if (
#     926     isdefined(self.inputs.use_temporal_deriv)
#     927     and self.inputs.use_temporal_deriv
#     928 ):
#     929     reg.insert(len(reg), regressor[0])
#
# File /om2/user/rfbrito/miniconda/envs/voice_img/lib/python3.10/site-packages/nipype/algorithms/modelgen.py:829, in SpecifySparseModel._gen_regress(self, i_onsets, i_durations, i_amplitudes, nscans)
#     827 if i_amplitudes:
#     828     if len(i_amplitudes) > 1:
# --> 829         timeline2[idx] = i_amplitudes[i]
#     830     else:
#     831         timeline2[idx] = i_amplitudes[0]
#
# IndexError: index 1423 is out of bounds for axis 0 with size 1392

# %%
image.load_img(nifti).get_data().shape
# Out:
# /tmp/ipykernel_11758/2984264774.py:1: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   image.load_img(nifti).get_data().shape
# (91, 109, 91, 39)

# %%
generate_sparse_scan_regressors(nifti, fitted_glm, task_json, events)
# Out:
# 230221-12:01:37,718 nipype.interface INFO:
# 	 Setting dt = 110 ms
#
# 230221-12:01:37,722 nipype.interface INFO:
# 	 response sum: 1.0000 max: 0.0231
# 230221-12:01:37,723 nipype.interface INFO:
# 	 reg_scale: 43.1973
# 230221-12:01:37,735 nipype.interface INFO:
# 	 Setting dt = 110 ms
#
# 230221-12:01:37,738 nipype.interface INFO:
# 	 response sum: 1.0000 max: 0.0231
# 230221-12:01:37,739 nipype.interface INFO:
# 	 reg_scale: 43.1973
# 230221-12:01:37,749 nipype.interface INFO:
# 	 Setting dt = 110 ms
#
# 230221-12:01:37,752 nipype.interface INFO:
# 	 response sum: 1.0000 max: 0.0231
# 230221-12:01:37,753 nipype.interface INFO:
# 	 reg_scale: 43.1973
#        exclamation  question  statement
# 0.0       0.000000  0.003826   0.000000
# 2.0       0.000000  0.375480   0.006373
# 4.0       0.000000  0.957418   0.422413
# 6.0       0.006373  0.836418   1.385247
# 8.0       0.419866  0.433824   1.784882
# ...            ...       ...        ...
# 192.0     1.370024  0.736968   0.282952
# 194.0     1.731050  0.631498   0.037888
# 196.0     1.170993  1.303254  -0.072783
# 198.0     0.924381  1.541333  -0.106679
# 200.0     1.046714  1.391873  -0.096875
#
# [101 rows x 3 columns]

# %%
sparse = True

models = pd.DataFrame([run_first_level_model(pvr['subject'],
                       pvr['task'],
                       pvr['session'],
                       int(pvr['run']),
                       sparse = sparse) 
 for pvr in parsed_valid_runs], columns= ['fitted_glm', 'selected_confounds', 'nifti', 'events'])
# Out:
# /om2/user/rfbrito/miniconda/envs/voice_img/lib/python3.10/site-packages/nilearn/glm/first_level/experimental_paradigm.py:89: UserWarning: Unexpected column `nonword` in events data will be ignored.
#   warnings.warn(("Unexpected column `{}` in events "
# voice875 nwr 1 1
# 230215-18:15:56,121 nipype.interface INFO:
# 	 Setting dt = 110 ms
#
# 230215-18:15:56,123 nipype.interface INFO:
# 	 response sum: 1.0000 max: 0.0231
# 230215-18:15:56,125 nipype.interface INFO:
# 	 reg_scale: 43.1973
# 230215-18:15:56,128 nipype.interface INFO:
# 	 Setting dt = 110 ms
#
# 230215-18:15:56,129 nipype.interface INFO:
# 	 response sum: 1.0000 max: 0.0231
# 230215-18:15:56,130 nipype.interface INFO:
# 	 reg_scale: 43.1973
# 230215-18:15:56,134 nipype.interface INFO:
# 	 Setting dt = 110 ms
#
# 230215-18:15:56,136 nipype.interface INFO:
# 	 response sum: 1.0000 max: 0.0231
# 230215-18:15:56,136 nipype.interface INFO:
# 	 reg_scale: 43.1973
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[63], line 3
#       1 sparse = True
# ----> 3 models = pd.DataFrame([run_first_level_model(pvr['subject'],
#       4                        pvr['task'],
#       5                        pvr['session'],
#       6                        int(pvr['run']),
#       7                        sparse = sparse)
#       8  for pvr in parsed_valid_runs], columns= ['fitted_glm', 'selected_confounds', 'nifti', 'events'])
#
# Cell In[63], line 3, in <listcomp>(.0)
#       1 sparse = True
# ----> 3 models = pd.DataFrame([run_first_level_model(pvr['subject'],
#       4                        pvr['task'],
#       5                        pvr['session'],
#       6                        int(pvr['run']),
#       7                        sparse = sparse)
#       8  for pvr in parsed_valid_runs], columns= ['fitted_glm', 'selected_confounds', 'nifti', 'events'])
#
# Cell In[34], line 44, in run_first_level_model(sub, task, ses, run, sparse, smoothing_fwhm)
#      41 print(sub,task,ses,run)
#      43 if sparse:
# ---> 44     sparse_scan_regressors = generate_sparse_scan_regressors(nifti, fitted_glm, task_json, events)
#      45     for event_type in sparse_scan_regressors.columns:
#      46         fitted_glm.design_matrices_[0][event_type] = sparse_scan_regressors[event_type]
#
# Cell In[3], line 15, in generate_sparse_scan_regressors(nifti, fitted_glm, task_json, events)
#      12 sparse_model.inputs.model_hrf = True
#      13 sparse_model.inputs.subject_info = modelgen.bids_gen_info(events,condition_column='trial_type')  # doctest: +SKIP
# ---> 15 regressors = sparse_model._list_outputs()['session_info'][0]['regress']
#      16 data = [v['val'] for v in regressors]
#      17 col = [t['name'] for t in regressors]
#
# File /om2/user/rfbrito/miniconda/envs/voice_img/lib/python3.10/site-packages/nipype/algorithms/modelgen.py:985, in SpecifySparseModel._list_outputs(self)
#     983 outputs = self._outputs().get()
#     984 if not hasattr(self, "_sessinfo"):
# --> 985     self._generate_design()
#     986 outputs["session_info"] = self._sessinfo
#     988 if isdefined(self.inputs.save_plot) and self.inputs.save_plot:
#
# File /om2/user/rfbrito/miniconda/envs/voice_img/lib/python3.10/site-packages/nipype/algorithms/modelgen.py:979, in SpecifySparseModel._generate_design(self, infolist)
#     977 else:
#     978     infolist = gen_info(self.inputs.event_files)
# --> 979 sparselist = self._generate_clustered_design(infolist)
#     980 super(SpecifySparseModel, self)._generate_design(infolist=sparselist)
#
# File /om2/user/rfbrito/miniconda/envs/voice_img/lib/python3.10/site-packages/nipype/algorithms/modelgen.py:958, in SpecifySparseModel._generate_clustered_design(self, infolist)
#     956 img = load(self.inputs.functional_runs[i])
#     957 nscans = img.shape[3]
# --> 958 reg, regnames = self._cond_to_regress(info, nscans)
#     959 if hasattr(infoout[i], "regressors") and infoout[i].regressors:
#     960     if not infoout[i].regressor_names:
#
# File /om2/user/rfbrito/miniconda/envs/voice_img/lib/python3.10/site-packages/nipype/algorithms/modelgen.py:922, in SpecifySparseModel._cond_to_regress(self, info, nscans)
#     910 scaled_onsets = scale_timings(
#     911     info.onsets[i],
#     912     self.inputs.input_units,
#     913     "secs",
#     914     self.inputs.time_repetition,
#     915 )
#     916 scaled_durations = scale_timings(
#     917     info.durations[i],
#     918     self.inputs.input_units,
#     919     "secs",
#     920     self.inputs.time_repetition,
#     921 )
# --> 922 regressor = self._gen_regress(
#     923     scaled_onsets, scaled_durations, amplitudes, nscans
#     924 )
#     925 if (
#     926     isdefined(self.inputs.use_temporal_deriv)
#     927     and self.inputs.use_temporal_deriv
#     928 ):
#     929     reg.insert(len(reg), regressor[0])
#
# File /om2/user/rfbrito/miniconda/envs/voice_img/lib/python3.10/site-packages/nipype/algorithms/modelgen.py:829, in SpecifySparseModel._gen_regress(self, i_onsets, i_durations, i_amplitudes, nscans)
#     827 if i_amplitudes:
#     828     if len(i_amplitudes) > 1:
# --> 829         timeline2[idx] = i_amplitudes[i]
#     830     else:
#     831         timeline2[idx] = i_amplitudes[0]
#
# IndexError: index 1423 is out of bounds for axis 0 with size 1392

# %%
contrast = create_contrast(fitted_glm.design_matrices_[0],'emosent')
zmap = create_zmap(fitted_glm,contrast)
threshold = 3

avg_img = mean_img(nifti)

coord = [-54,0,3]

plot_stat_map(zmap, bg_img=avg_img, threshold=threshold,
              display_mode='ortho', cut_coords=coord,
              black_bg=True,
              title=f'{task}, {sub} (Z>{threshold}), sparse scan {sparse}')
plt.show()

# %%
contrast = create_contrast(fitted_glm.design_matrices_[0],'emosent')
zmap = create_zmap(fitted_glm,contrast)
threshold = 3.5

avg_img = mean_img(nifti)

coord = [-54,0,3]

plot_stat_map(zmap, bg_img=avg_img, threshold=threshold,
              display_mode='ortho', cut_coords=coord,
              black_bg=True,
              title=f'{task}, {sub} (Z>{threshold}), sparse scan {sparse}')
plt.show()

# %%
unthresholded_zmap = zmap.get_fdata()
thresholded_zmap = (unthresholded_zmap > threshold)*unthresholded_zmap

# %%
from nilearn.image import new_img_like

thresh_image = new_img_like(nifti, thresholded_zmap)

# %%
plot_stat_map(thresh_image, bg_img=avg_img,
              display_mode='ortho', cut_coords=coord,
              black_bg=True,
              title=f'Thresholded, {task}, {sub} (Z>{threshold}), sparse scan {sparse}')

# %%
#first level glm model


def run_first_level_model(sub,task,ses,run,sparse,smoothing_fwhm=5):
    #memory = './nilearn_cache' #change if desired
    space='MNI152NLin6Asym' #change if desired
    
    task_json = open(f"../../task-{task}_bold.json")
    task_json=json.load(task_json)
    TR=task_json['RepetitionTime']
    
    nifti = glob.glob(f'../../derivatives/fmriprep/sub-{sub}/ses-{ses}/func/sub-{sub}*task-{task}*run-{run}*{space}*preproc*nii.gz')[0]
    events = glob.glob(f'/om/project/voice/bids/data/sub-{sub}/ses-{ses}/func/sub-{sub}*task-{task}*run-0{run}*events.tsv')
    
    'voice*/ses-*/func/*{task}*events.tsv'
    #mask = glob.glob(f'../../derivatives/ses-{ses}/sub-{sub}/ses-{ses}/func/sub-{sub}*task-{task}*run-{run}*{space}*brain_mask.nii.gz')[0]

    selected_confounds=get_confounds(sub,task,ses,run)

    #choose middle slice as reference since fmriprep default for slice timing correction
    #already accounting for drift and high pass filter with cosine regressors (I believe)
    #might want to change to this at some point: minimize_memory=False
    #spm + derivative + disperson should account for undershoot and slight variances in HRF across ppl/regions
    #satra: twice the voxel resolution, so probs 4
    #satra: signal_scaling look more into it, doesn't affect stats but does affect effect size 
    glm = FirstLevelModel(t_r=TR,
                          smoothing_fwhm=smoothing_fwhm, 
                          noise_model='ar1',
                          drift_model=None,
                          standardize=False,
                          hrf_model='spm',
                          high_pass=.01)
        #t_r = TR, #mask_img=mask,
        #slice_time_ref=0.5, smoothing_fwhm=6.0, hrf_model='spm + derivative + dispersion', drift_model=None,
        #high_pass=None, drift_order=4, standardize=False, signal_scaling=False, noise_model='ar1',
        # minimize_memory=True, verbose=0, n_jobs=-2)
    #memory=memory,

    fitted_glm = glm.fit(nifti, events=events[0], confounds=selected_confounds)
    
    #if sparse:
    #    sparse_scan_regressors = generate_sparse_scan_regressors(nifti, fitted_glm, task_json, events)
    #    for event_type in sparse_scan_regressors.columns:
    #        fitted_glm.design_matrices_[0][event_type] = sparse_scan_regressors[event_type]

    return [fitted_glm, selected_confounds, nifti, events]

# %%
def find_populated_events(events_path_pattern):

    #get list of all events file in bids directory (using old location) per task as df
    #pop_events = pd.DataFrame(glob.glob(f'/om/project/voice/bids/data/sub-voice*/ses-*/func/*{task}*events.tsv'), columns= ['events_file'])

    pop_events = pd.DataFrame(glob.glob(events_path_pattern), columns= ['events_file'])

    #use pd empty attribute to determine if file is empty or not. 
    #invert the boolean value as I want to know if it is popualated or not
    pop_events['populated'] = [not pd.read_table(f).empty for f in pop_events.events_file]

    pop_events['task'] = [parse_file_entities(file)['task'] for file in pop_events.events_file]

    return pop_events

# %%
#get confounds for any subject and task

def get_confounds(sub,task,ses,run):

    all_confounds = pd.read_csv(f"../../derivatives/fmriprep/sub-{sub}/ses-{ses}/func/sub-{sub}_ses-{ses}_task-{task}_run-{run}_desc-confounds_timeseries.tsv", sep = '\t')
    
    all_confounds_json = open(f"../../derivatives/fmriprep/sub-{sub}/ses-{ses}/func/sub-{sub}_ses-{ses}_task-{task}_run-{run}_desc-confounds_timeseries.json")
    all_confounds_json=json.load(all_confounds_json)
    
    
    #typically included rigid body motion (or those plus squares and derivatives if desired, then must comment out top line and uncomment bottom 3)
    motion_params = ['trans_x', 'trans_y', 'trans_z','rot_x','rot_y','rot_z']
    # motion_trans_params = [col for col in all_confounds.columns if 'trans' in col] #change to these squares and derivatives if desired
    # motion_rot_params = [col for col in all_confounds.columns if 'rot' in col] #change to these if desired
    # motion_params=motion_trans_params+motion_rot_params #change to these if desired

    
    #individual col with single 1 for timepoint of motion
    #motion_outliers = [col for col in all_confounds.columns if 'motion_outlier' in col]  
    
    
    #for low freq signal drift
    #cannot include this and high-pass temp filter bc already removes low freq fluc
    #required if using aCompCor (or tCompCor)
    #cosine_regressors = [col for col in all_confounds.columns if 'cosine' in col] 
    
    
    #these can be adjusted to be from the combined wm csf, for example
    #doesn't make sense to use csf and wm signal regression if using these according to fmriprep documentation
    #6 is rule of thumb; can pick diff number or specific amount of variance explained
    #TO DO clarify if edge/crown regressors are already part of compcor -- unclear in docs and can't find separate regressor in tsv
    #num_a_comp_cors=6
    #a_comp_cors = []
    #for i in range(num_a_comp_cors):
    #    a_comp_cors.append('a_comp_cor_{:02d}'.format(i))
    
        
    #if taking ICA AROMA denoised niftis (~desc-smoothAROMAnonaggr_bold.nii.gz), can't also include ICA noise regressors & MUST drop non-steady state vols
    #here we are taking instead the ICA AROMA regressors: aroma_motion_XX
    #aroma_regressors_all = [col for col in all_confounds.columns if 'aroma' in col]
    #aroma_regressors_noise=[]
    #TO DO: excluding for now, but double check on this!
#     for regr in aroma_regressors_all:
#         json_name ='aroma_motion_'+str(int(regr.split('aroma_motion_')[1]))
#         if all_confounds_json[json_name]['MotionNoise']==True:
#             aroma_regressors_noise.append(regr)
        

    #we need to filter out non-steady state volumes if using cosine regressors, ICA AROMA and CompCor regressors...    
    #non_steady_state_regressors = [col for col in all_confounds.columns if 'non_steady_state' in col]
           
    #TO DO: not sure if CSF should be kept since already have aCompCors (excluding for now)
    #selected_confounds = all_confounds[['framewise_displacement']+motion_params+motion_outliers+cosine_regressors+a_comp_cors+aroma_regressors_noise+non_steady_state_regressors].copy()

    selected_confounds = all_confounds[['framewise_displacement']+motion_params].copy()

    #get rid of nas in first row of derivative and framewise displacement cols
    for col in selected_confounds.columns:
        if ('derivative' in col) or ('framewise_displacement' in col):
            if pd.isna(selected_confounds[col][0]):
                selected_confounds[col][0]=0

    return selected_confounds

# %%
def generate_sparse_scan_regressors(nifti, fitted_glm, task_json, events):
    
    TR=task_json['RepetitionTime']
    DT=task_json['DelayTime']

    sparse_model = modelgen.SpecifySparseModel()
    sparse_model.inputs.input_units = 'secs'
    sparse_model.inputs.functional_runs = nifti
    sparse_model.inputs.time_repetition = TR
    sparse_model.inputs.time_acquisition = TR - DT
    sparse_model.inputs.high_pass_filter_cutoff = 128.
    sparse_model.inputs.model_hrf = True
    sparse_model.inputs.subject_info = modelgen.bids_gen_info(events,condition_column='trial_type')  # doctest: +SKIP

    regressors = sparse_model._list_outputs()['session_info'][0]['regress']
    data = [v['val'] for v in regressors]
    col = [t['name'] for t in regressors]
    df_regressors = pd.DataFrame(data).T
    df_regressors.columns = col
    df_regressors.index = fitted_glm.design_matrices_[0].index
    
    return df_regressors

# %%
#plot design matrix for one subject
#not needed to be run unless one wants to see it

def show_design_matrix(fitted_glm):
    for design_matrix in fitted_glm.design_matrices_:
        plot_design_matrix(design_matrix)
        plt.show()

# %%
def create_contrast(design_matrix, task):
    #fmri_img = concat_imgs(nifti)
    #mean_img = mean_img(fmri_img)
    
    if task == 'pataka':
        clear = np.zeros(design_matrix.shape[1])
        clear[0] = 1
        normal = np.zeros(design_matrix.shape[1])
        normal[1] = 1
        rapid = np.zeros(design_matrix.shape[1])
        rapid[2] = 1
        silent = np.zeros(design_matrix.shape[1])
        silent[3] = 1


        conditions = {
            'clear': clear,
            'normal': normal,
            'rapid': rapid,
            'silent': silent
        }

        speech_contrast = 0.33*conditions['clear'] + 0.33*conditions['normal'] + 0.33*conditions['rapid'] - conditions['silent']
    
    if task == 'emosent':
        happy= np.zeros(design_matrix.shape[1])
        happy[0] = 1
        neutral= np.zeros(design_matrix.shape[1])
        neutral[1] = 1
        sad = np.zeros(design_matrix.shape[1])
        sad[2] = 1
        silent = np.zeros(design_matrix.shape[1])
        silent[3] = 1
        
        conditions = {
            'happy': happy,
            'neutral': neutral,
            'sad': sad,
            'silent': silent
        }
        
        speech_contrast = 0.33*conditions['happy'] + 0.33*conditions['neutral'] + 0.33*conditions['sad'] - conditions['silent']
    
    if task == 'nwr':
        two = np.zeros(design_matrix.shape[1])
        two[0] = 1
        three= np.zeros(design_matrix.shape[1])
        three[1] = 1
        four = np.zeros(design_matrix.shape[1])
        four[2] = 1
        five = np.zeros(design_matrix.shape[1])
        five[3] = 1
        rest = np.zeros(design_matrix.shape[1])
        rest[4] = 1
        
        conditions = {
            '2': two,
            '3': three,
            '4': four,
            '5': five,
            'Rest' : rest
        }
        
        speech_contrast = 0.25*conditions['2'] + 0.25*conditions['3'] + 0.25*conditions['4'] + 0.25*conditions['5'] - 0.25*conditions['Rest']
    
    if task == 'vowel':
        aah = np.zeros(design_matrix.shape[1])
        aah[0] = 1
        eee= np.zeros(design_matrix.shape[1])
        eee[1] = 1
        ooh = np.zeros(design_matrix.shape[1])
        ooh[2] = 1
        silent = np.zeros(design_matrix.shape[1])
        silent[3] = 1
        
        conditions = {
            'aah': aah,
            'eee': eee,
            'ooh': ooh,
            'silent': silent
        }
        
        speech_contrast = 0.33*conditions['aah'] + 0.33*conditions['eee'] + 0.33*conditions['ooh'] - conditions['silent']
    
    return speech_contrast

#plot_contrast_matrix(active_minus_rest, design_matrix=design_matrix)

# %%
def create_zmap(fitted_glm, speech_contrast):
    
    zmap = fitted_glm.compute_contrast(speech_contrast,
                                  output_type='z_score')
    
    return zmap

# %%
# d = pop_events.groupby('task')
# first = {}

# for g, v in d:
#     first[g]=v.iloc[0] 
    
#first.keys()
#pd.read_table(first['vowel'].events_file).trial_type.unique()
#first['vowel'].events_file

# %%
#create all desired contrasts

#satra: combine image and arrow regressors because highly collinear!!! can do a correlation matrix of all regressors of design matrix to see if we need to throw out a contrast/subject (anything >0.3 or 0.4 is a high correlation)
#on second thought might be ok to keep them apart

def make_localizer_contrasts(design_matrix,task,selected_confounds):
    """ returns a dictionary of contrasts, given the design matrix"""

    # first generate canonical contrasts based on the design matrix columns 
    contrast_matrix = np.eye(design_matrix.shape[1])
    canonical_contrasts = dict([(column, contrast_matrix[i])
                      for i, column in enumerate(design_matrix.columns)])
    
    
    #initialize dictionary of contrasts desired for analysis of respective task
    final_contrasts={}
    
    #initialize list of complex contrasts, which are combinations of the canonical contrasts
    task_contrasts = []
    
    #complex contrasts for nback task (must include a '-' or '+' and be made up of canonical contrasts)
    if task == 'nback':
        task_contrasts = ['twoback-zeroback']
    
    #complex contrasts for mid task (must include a '-' or '+' and be made up of canonical contrasts)
    if task == 'mid':
        task_contrasts = ['HiRewCue-NeuCue', #high reward anticipation
                          'LoRewCue-NeuCue', #low reward anticipation
                          'HiLossCue-NeuCue', #high loss anticipation
                          'LoLossCue-NeuCue', #low loss anticipation
                          
                          'HiWin-NeuHit', #high reward outcome cp. to neutral hit
                          'LoWin-NeuHit', #low reward outcome cp. to neutral hit
                          'HiWin-HiNoWin', #high reward outcome cp. to high reward miss
                          'LoWin-LoNoWin', #low reward outcome cp. to low reward miss
                          
                          'HiLoss-NeuMiss', #high loss cp. to neutral miss
                          'LoLoss-NeuMiss', #low loss cp. to neutral miss
                          'HiLoss-AvoidHiLoss', #high loss cp. to avoid high loss
                          'LoLoss-AvoidLoLoss', #low loss cp. to avoid low loss
                          
                          'HiRewCue+LoRewCue-NeuCue', #combined reward anticipation
                          'HiLossCue+LoLossCue-NeuCue', #combined loss anticipation
                          
                          'HiWin+LoWin-NeuHit', #combined reward outcome cp. to neutral hit
                          'HiWin+LoWin-HiNoWin-LoNoWin', #combined reward outcome cp. to combined reward miss
                          
                          'HiLoss+LoLoss-NeuMiss', #combined loss cp. to neutral miss
                          'HiLoss+LoLoss-AvoidHiLoss-AvoidLoLoss' #combined loss cp. to combined avoid loss  
                         ]
    
    #complex contrasts for sst task (must include a '-' or '+' and be made up of canonical contrasts)
    #TO DO: need to add contrasts to capture comparison between MJ trial and Neutral trial for arrow/stop 
    #TO DO: need to add contrasts to capture comparison between MJ trial and Neutral trial for images
#     if task == 'sst':
#         print('here')
#         task_contrasts = ['N_SuccStop_arrow-N_Go_arrow', #correct inhibition normal
#                           'MJ_SuccStop_arrow-MJ_Go_arrow', #correct inhibition MJ
#                           'N_UnsuccStop_arrow-N_Go_arrow', #incorrect inhibition normal
#                           'MJ_UnsuccStop_arrow-MJ_Go_arrow', #incorrect inhibition MJ
#                           'N_UnsuccStop_arrow-N_SuccStop_arrow', #successful inhibitory control normal
#                           'MJ_UnsuccStop_arrow-MJ_SuccStop_arrow' #successful inhibitory control MJ
#                          ]
    
    #for loop that creates complex contrasts based on the string names from the task_contrasts list created above
    for task_contrast in task_contrasts:
        #split complex contrast string into a list of canonical contrasts separated by '-' or '+' 
        #'-' and '+' are maintained in the list due to the () around the deliminator specified in re.split
        events = re.split('([\-\+])', task_contrast)
        
        #check if all canonical contrasts needed for a given complex contrast were present in a subject's data
        #note that sometimes a participant eg. never had a miss on a type of trial, so the miss regressor doesn't exist 
        #can comment out print statements to see which contrasts are being generated vs. for which events are missing
        if len(set(events).intersection(set(canonical_contrasts.keys()))) < np.ceil(len(events)/2):
            #print(f'issue with: {task_contrast}')
            continue
        #print(f'checking passed for {task_contrast}')
        
        #set up placeholder for array containing matrix for the complex contrast
        complex_contrast = 0
        #set up how the canonical contrasts will be added/subtracted to create the complex contrast
        math_sign = '+'
        plus_multiplier = 1
        minus_multiplier = 1
        #this only applies to the mid task, since the nback and sst tasks' complex contrasts are only made up of two canonical contrasts
        #if mid list consists of 5 elements (i.e. 3 canonical contrasts and 2 math symbols), there is always 1 '+' and 1 '-' (in addition to the implied '+ at the beginning)
        #in that case, we need to multiply the 2 canonical constrasts after the '+' and implied '+' by 0.5
        if len(events) == 5:
            plus_multiplier = 0.5
        #if mid list consists of 7 elements (i.e. 4 canonical contrasts and 3 math symbols), there is always 1 '+' and 2 '-' (in addition to the implied '+ at the beginning)
        #in that case, we need to multiply the 4 canonical constrasts by 0.5
        if len(events) == 7:
            minus_multiplier = 0.5
            plus_multiplier = 0.5
            
        #do the complex contrast calculation
        for el in events:
            #math_sign starts of with '+' as set up above since the first canonical contrast has an implied '+' at the beginning (added to the 0 that we used to initialize the complex contrast)
            if el in ['+','-']:
                math_sign = el
            #if current list element isn't a math sign, then it's a canonical contrast and we add/subtract based on the math sign we set
            #we also multiply the canonical contrast by 1 (default) or 0.5 (certain mid complex contrasts)
            else:
                if math_sign == '+':
                    complex_contrast = complex_contrast + plus_multiplier*canonical_contrasts[el]
                if math_sign == '-':
                    complex_contrast = complex_contrast - minus_multiplier*canonical_contrasts[el]
        #at the end we store the created complex contrast        
        final_contrasts[task_contrast] = complex_contrast       
                
        
    #add a nuisance regressor contrast to the final set of contrasts that includes all nuisance regressors
    #firs set up zeros matrix of correct shape
    final_contrasts['nuisance_regressors']=np.zeros(design_matrix.shape[1])
    #this iteratively adds a 1 in place of all the confounds in the zeros matrix
    for confound in selected_confounds.columns:
        final_contrasts['nuisance_regressors']=final_contrasts['nuisance_regressors']+canonical_contrasts[confound]
    
    #return dictionary of all complex contrasts
    return final_contrasts

# %%
#loop over all subjects to store first level GLM results

def save_first_level_outputs(input_list):
    sub,task,ses,run = input_list
    print(f'Now processing subject {sub} for task {task} in session {ses} run {run}')
    
    #check that input exists
    nifti = glob.glob(f'../../../derivatives/ses-{ses}/sub-{sub}/ses-{ses}/func/sub-{sub}*task-{task}*rec-unco*run-{run}*{space}*preproc*nii.gz')
    if not nifti: #checks if list is empty
        print(f'1st level input does not exist for subject {sub}, session {ses}, run {run} and task {task}. Cannot generate output.')
        return
    
    #check that output does not exist
    output = glob.glob(f'../../../derivatives/nilearn/first_level/sub-{sub}/ses-{ses}/task-{task}/sub-{sub}_ses-{ses}_task-{task}_rec-unco_run-{run}_contrast-*_effect_size.nii.gz')
    if output: #checks if list is not empty
        print(f'At least partial 1st level output exists for subject {sub}, session {ses}, run {run} and task {task}. This must be deleted for before generating new output.')
        return    
    
    #run first level model 
    #note confounds are subject specific! 
    fitted_glm, selected_confounds = run_first_level_model(sub,task,ses,run)         
    
    #define contrasts for task
    #note constrasts are subject specific due to varying numbers of confounders        
    contrasts = make_localizer_contrasts(fitted_glm.design_matrices_[0],task,selected_confounds)

    for contrast in contrasts.keys():
        #calculate contrast maps for all contrasts
        #satra: f test for all nuisance regressors and look at map to see what areas are affected 
        #TO DO: F is a 2D contrast, so unclear if that makes sense/works if nuisance contrast is 1D array
        #F usually means is any of these 1D contrasts significant?
        #can also just not set stat_type and will default to t or F, depending on dim of contrast
        if contrast == 'nuisance_regressors':
            contrast_output = fitted_glm.compute_contrast(contrasts[contrast], output_type='all',stat_type='F')
        else:   
            contrast_output = fitted_glm.compute_contrast(contrasts[contrast], output_type='all',stat_type='t')
        
        #create paths to output dir if not exist
        derivatives_path = '../../../derivatives'
        nilearn_output_path = os.path.join(derivatives_path, 'nilearn','first_level',f'sub-{sub}',f'ses-{ses}',f'task-{task}')
        if not os.path.isdir(nilearn_output_path):
            os.makedirs (nilearn_output_path)
            
        #save contrast maps to files
        contrast_output['effect_size'].to_filename(f'../../../derivatives/nilearn/first_level/sub-{sub}/ses-{ses}/task-{task}/sub-{sub}_ses-{ses}_task-{task}_rec-unco_run-{run}_contrast-{contrast}_effect_size.nii.gz')
        contrast_output['effect_variance'].to_filename(f'../../../derivatives/nilearn/first_level/sub-{sub}/ses-{ses}/task-{task}/sub-{sub}_ses-{ses}_task-{task}_rec-unco_run-{run}_contrast-{contrast}_effect_variance.nii.gz')
        contrast_output['z_score'].to_filename(f'../../../derivatives/nilearn/first_level/sub-{sub}/ses-{ses}/task-{task}/sub-{sub}_ses-{ses}_task-{task}_rec-unco_run-{run}_contrast-{contrast}_z_score.nii.gz')
        contrast_output['stat'].to_filename(f'../../../derivatives/nilearn/first_level/sub-{sub}/ses-{ses}/task-{task}/sub-{sub}_ses-{ses}_task-{task}_rec-unco_run-{run}_contrast-{contrast}_stat.nii.gz')
        contrast_output['p_value'].to_filename(f'../../../derivatives/nilearn/first_level/sub-{sub}/ses-{ses}/task-{task}/sub-{sub}_ses-{ses}_task-{task}_rec-unco_run-{run}_contrast-{contrast}_p_value.nii.gz')
    
    return

# %%
#select runs, tasks and sessions to process
#task_list=['sst','nback','mid']
#task_list=['nback','mid'] #since sst contrast isn't finalized
#ses_list=['baseline','1year']
#run_list=['1','2','3']

task_list=['nback']
ses_list=['baseline','1year']
run_list=['1','2','3']


# for task in task_list:
#     for ses in ses_list:
#         for run in run_list:
#             #find all subjects who have task niftis and events.tsv for this task, session & run
#             space='MNI152NLin6Asym' #change if desired
#             nifti = (glob.glob(f'../../../derivatives/ses-{ses}/sub-*/ses-{ses}/func/sub-*task-{task}*rec-unco*run-{run}*{space}*preproc*nii.gz'))
#             subjs_nifti = set([path.split(f'/ses-{ses}/')[1].split('-')[-1] for path in nifti])
#             events = (glob.glob(f'../../../sub-*/ses-{ses}/func/sub-*task-{task}*rec-unco*run-{run}*events.tsv'))
#             subjs_events = set([path.split(f'/ses-{ses}/')[0].split('-')[-1] for path in events if pd.read_csv(path).shape[0] != 0])
#             subjs = list(subjs_nifti.intersection(subjs_events))
#             for sub in subjs:
#                 if sub == 'MM273':
#                 #TO DO: this will become input to the script
#                 #if sub not in ['MM086','MM273']: #for 1year, run1: missing NeuMiss, NeuHit, respectively
#                 #if sub not in ['MM254','MM273']: #for 1year, run2: missing HiLoss, NeuHit, respectively
#                 #if sub not in ['HC023','HC035','MM254','MM283']:  #for baseline, run1: HC023 doesn't have NeuMiss; HC035 doesn't have NeuHit; MM254 doesn't have HiWin; MM283 doesn't have NeuMiss
#                 #if sub not in ['HC009','HC013','HC020','HC023','MM147','MM197','MM199','MM254','MM340']: #for baseline, run2: HC009 is missing NeuHit, HC013 is missing NeuHit; HC020 is missing HiNoWin;HC023 is missing HiLoss; MM147 is missing HiLoss; MM197 is missing NeuHit; MM199 is missing HiLoss; MM254 is missing HiWin; MM340 is missing NeuHit
#                 #if sub:
#                     input_list = sub,task,ses,run
#                     save_first_level_outputs(input_list)


inputs = []

for task in task_list:
    for ses in ses_list:
        for run in run_list:
            #find all subjects who have task niftis and events.tsv for this task, session & run
            space='MNI152NLin6Asym' #change if desired
            nifti = (glob.glob(f'../../../derivatives/ses-{ses}/sub-*/ses-{ses}/func/sub-*task-{task}*rec-unco*run-{run}*{space}*preproc*nii.gz'))
            subjs_nifti = set([path.split(f'/ses-{ses}/')[1].split('-')[-1] for path in nifti])
            events = (glob.glob(f'../../../sub-*/ses-{ses}/func/sub-*task-{task}*rec-unco*run-{run}*events.tsv'))
            subjs_events = set([path.split(f'/ses-{ses}/')[0].split('-')[-1] for path in events if pd.read_csv(path).shape[0] != 0])
            subjs = list(subjs_nifti.intersection(subjs_events))
            
            for sub in subjs:
                inputs.append([sub,task,ses,run])


# starting the monitoring
tracemalloc.start()

print(len(inputs))
n=20
input_chunks = [inputs[i::n] for i in range(n)]

with concurrent.futures.ProcessPoolExecutor() as executor:
    for input_chunk in input_chunks:
        for single_input, prime in zip(input_chunk, executor.map(save_first_level_outputs, input_chunk)):
            print(' '.join(single_input) + ': processing done')
executor.shutdown()

# displaying the memory
print(tracemalloc.get_traced_memory())
 
# stopping the library
tracemalloc.stop()
# Out:
# 59
# Now processing subject MM096 for task nback in session 1year run 1
# Now processing subject MM334 for task nback in session 1year run 1Now processing subject MM100 for task nback in session 1year run 1
#
# At least partial 1st level output exists for subject MM096, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# At least partial 1st level output exists for subject MM100, session 1year, run 1 and task nback. This must be deleted for before generating new output.At least partial 1st level output exists for subject MM334, session 1year, run 1 and task nback. This must be deleted for before generating new output.
#
# Now processing subject MM315 for task nback in session 1year run 1
# Now processing subject MM054 for task nback in session 1year run 1Now processing subject MM148 for task nback in session 1year run 1
#
# At least partial 1st level output exists for subject MM315, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# At least partial 1st level output exists for subject MM148, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# At least partial 1st level output exists for subject MM054, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# Now processing subject MM095 for task nback in session 1year run 1Now processing subject MM151 for task nback in session 1year run 1
# Now processing subject MM062 for task nback in session 1year run 1
#
# At least partial 1st level output exists for subject MM151, session 1year, run 1 and task nback. This must be deleted for before generating new output.At least partial 1st level output exists for subject MM095, session 1year, run 1 and task nback. This must be deleted for before generating new output.
#
# At least partial 1st level output exists for subject MM062, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# Now processing subject MM131 for task nback in session 1year run 1Now processing subject MM196 for task nback in session 1year run 1Now processing subject MM239 for task nback in session 1year run 1
#
#
# At least partial 1st level output exists for subject MM131, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# At least partial 1st level output exists for subject MM239, session 1year, run 1 and task nback. This must be deleted for before generating new output.At least partial 1st level output exists for subject MM196, session 1year, run 1 and task nback. This must be deleted for before generating new output.
#
# Now processing subject MM188 for task nback in session 1year run 1Now processing subject MM179 for task nback in session 1year run 1Now processing subject MM330 for task nback in session 1year run 1
#
#
# At least partial 1st level output exists for subject MM179, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# At least partial 1st level output exists for subject MM188, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# At least partial 1st level output exists for subject MM330, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# Now processing subject MM140 for task nback in session 1year run 1Now processing subject MM127 for task nback in session 1year run 1
# Now processing subject MM195 for task nback in session 1year run 1
#
# At least partial 1st level output exists for subject MM140, session 1year, run 1 and task nback. This must be deleted for before generating new output.At least partial 1st level output exists for subject MM127, session 1year, run 1 and task nback. This must be deleted for before generating new output.At least partial 1st level output exists for subject MM195, session 1year, run 1 and task nback. This must be deleted for before generating new output.
#
#
# Now processing subject MM091 for task nback in session 1year run 1Now processing subject MM232 for task nback in session 1year run 1Now processing subject MM284 for task nback in session 1year run 1
#
#
# At least partial 1st level output exists for subject MM091, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# At least partial 1st level output exists for subject MM284, session 1year, run 1 and task nback. This must be deleted for before generating new output.At least partial 1st level output exists for subject MM232, session 1year, run 1 and task nback. This must be deleted for before generating new output.
#
# Now processing subject MM197 for task nback in session 1year run 1Now processing subject MM240 for task nback in session 1year run 1
# Now processing subject MM254 for task nback in session 1year run 1
#
# At least partial 1st level output exists for subject MM197, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# At least partial 1st level output exists for subject MM240, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# At least partial 1st level output exists for subject MM254, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# Now processing subject MM230 for task nback in session 1year run 1Now processing subject MM198 for task nback in session 1year run 1
# Now processing subject MM199 for task nback in session 1year run 1
#
# At least partial 1st level output exists for subject MM230, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# At least partial 1st level output exists for subject MM199, session 1year, run 1 and task nback. This must be deleted for before generating new output.At least partial 1st level output exists for subject MM198, session 1year, run 1 and task nback. This must be deleted for before generating new output.
#
# Now processing subject MM028 for task nback in session 1year run 1
# Now processing subject MM249 for task nback in session 1year run 1Now processing subject MM224 for task nback in session 1year run 1
#
# At least partial 1st level output exists for subject MM028, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# At least partial 1st level output exists for subject MM224, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# At least partial 1st level output exists for subject MM249, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# MM096 nback 1year 1: processing done
# MM334 nback 1year 1: processing done
# MM100 nback 1year 1: processing done
# MM054 nback 1year 1: processing done
# MM148 nback 1year 1: processing done
# MM315 nback 1year 1: processing done
# MM095 nback 1year 1: processing done
# MM151 nback 1year 1: processing done
# MM062 nback 1year 1: processing done
# MM196 nback 1year 1: processing done
# MM131 nback 1year 1: processing done
# MM239 nback 1year 1: processing done
# MM188 nback 1year 1: processing done
# MM179 nback 1year 1: processing done
# MM330 nback 1year 1: processing done
# MM140 nback 1year 1: processing done
# MM127 nback 1year 1: processing done
# MM195 nback 1year 1: processing done
# MM091 nback 1year 1: processing done
# MM232 nback 1year 1: processing done
# MM284 nback 1year 1: processing done
# MM197 nback 1year 1: processing done
# MM240 nback 1year 1: processing done
# MM254 nback 1year 1: processing done
# MM230 nback 1year 1: processing done
# MM198 nback 1year 1: processing done
# MM199 nback 1year 1: processing done
# MM028 nback 1year 1: processing done
# MM249 nback 1year 1: processing done
# MM224 nback 1year 1: processing done
# Now processing subject MM207 for task nback in session 1year run 1Now processing subject MM248 for task nback in session 1year run 1
# Now processing subject MM103 for task nback in session 1year run 1
#
# At least partial 1st level output exists for subject MM207, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# At least partial 1st level output exists for subject MM248, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# At least partial 1st level output exists for subject MM103, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# Now processing subject MM193 for task nback in session 1year run 1Now processing subject MM132 for task nback in session 1year run 1
#
# At least partial 1st level output exists for subject MM193, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# Now processing subject MM160 for task nback in session 1year run 1
# At least partial 1st level output exists for subject MM132, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# At least partial 1st level output exists for subject MM160, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# Now processing subject MM075 for task nback in session 1year run 1Now processing subject MM217 for task nback in session 1year run 1
#
# At least partial 1st level output exists for subject MM075, session 1year, run 1 and task nback. This must be deleted for before generating new output.At least partial 1st level output exists for subject MM217, session 1year, run 1 and task nback. This must be deleted for before generating new output.
#
# Now processing subject MM227 for task nback in session 1year run 1
# At least partial 1st level output exists for subject MM227, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# Now processing subject MM044 for task nback in session 1year run 1Now processing subject MM147 for task nback in session 1year run 1Now processing subject MM166 for task nback in session 1year run 1
#
#
# At least partial 1st level output exists for subject MM147, session 1year, run 1 and task nback. This must be deleted for before generating new output.At least partial 1st level output exists for subject MM044, session 1year, run 1 and task nback. This must be deleted for before generating new output.
#
# At least partial 1st level output exists for subject MM166, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# Now processing subject MM085 for task nback in session 1year run 1Now processing subject MM273 for task nback in session 1year run 1
# Now processing subject MM122 for task nback in session 1year run 1
#
# At least partial 1st level output exists for subject MM085, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# At least partial 1st level output exists for subject MM273, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# At least partial 1st level output exists for subject MM122, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# Now processing subject MM135 for task nback in session 1year run 1Now processing subject MM241 for task nback in session 1year run 1Now processing subject MM112 for task nback in session 1year run 1
#
#
# At least partial 1st level output exists for subject MM135, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# At least partial 1st level output exists for subject MM241, session 1year, run 1 and task nback. This must be deleted for before generating new output.At least partial 1st level output exists for subject MM112, session 1year, run 1 and task nback. This must be deleted for before generating new output.
#
# Now processing subject MM154 for task nback in session 1year run 1Now processing subject MM053 for task nback in session 1year run 1Now processing subject MM104 for task nback in session 1year run 1
#
#
# At least partial 1st level output exists for subject MM053, session 1year, run 1 and task nback. This must be deleted for before generating new output.At least partial 1st level output exists for subject MM154, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# At least partial 1st level output exists for subject MM104, session 1year, run 1 and task nback. This must be deleted for before generating new output.
#
# Now processing subject MM136 for task nback in session 1year run 1
# Now processing subject MM221 for task nback in session 1year run 1Now processing subject MM256 for task nback in session 1year run 1
#
# At least partial 1st level output exists for subject MM136, session 1year, run 1 and task nback. This must be deleted for before generating new output.At least partial 1st level output exists for subject MM221, session 1year, run 1 and task nback. This must be deleted for before generating new output.
#
# At least partial 1st level output exists for subject MM256, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# Now processing subject MM129 for task nback in session 1year run 1Now processing subject MM086 for task nback in session 1year run 1
#
# Now processing subject MM286 for task nback in session 1year run 2
# At least partial 1st level output exists for subject MM129, session 1year, run 1 and task nback. This must be deleted for before generating new output.
# At least partial 1st level output exists for subject MM086, session 1year, run 1 and task nback. This must be deleted for before generating new output.At least partial 1st level output exists for subject MM286, session 1year, run 2 and task nback. This must be deleted for before generating new output.
#
# Now processing subject MM301 for task nback in session 1year run 1Now processing subject MM177 for task nback in session 1year run 1
#
# At least partial 1st level output exists for subject MM177, session 1year, run 1 and task nback. This must be deleted for before generating new output.At least partial 1st level output exists for subject MM301, session 1year, run 1 and task nback. This must be deleted for before generating new output.
#
# MM207 nback 1year 1: processing done
# MM103 nback 1year 1: processing done
# MM248 nback 1year 1: processing done
# MM193 nback 1year 1: processing done
# MM132 nback 1year 1: processing done
# MM160 nback 1year 1: processing done
# MM227 nback 1year 1: processing done
# MM075 nback 1year 1: processing done
# MM217 nback 1year 1: processing done
# MM044 nback 1year 1: processing done
# MM147 nback 1year 1: processing done
# MM166 nback 1year 1: processing done
# MM085 nback 1year 1: processing done
# MM273 nback 1year 1: processing done
# MM122 nback 1year 1: processing done
# MM135 nback 1year 1: processing done
# MM241 nback 1year 1: processing done
# MM112 nback 1year 1: processing done
# MM154 nback 1year 1: processing done
# MM053 nback 1year 1: processing done
# MM104 nback 1year 1: processing done
# MM136 nback 1year 1: processing done
# MM221 nback 1year 1: processing done
# MM256 nback 1year 1: processing done
# MM129 nback 1year 1: processing done
# MM086 nback 1year 1: processing done
# MM286 nback 1year 2: processing done
# MM301 nback 1year 1: processing done
# MM177 nback 1year 1: processing done
# (42203, 151073)

# %%
#TO DO: ADJUST START TIME???

# %%
 #load all the events.tsv file as dataframes and then add columns for each label
    #events_w_metadata_all = []
    #for f in Path('../data/counts_pataka/').glob('*'):
    #import re
#re.split('_',name)
#     test = !ls /om/project/voice/bids/data/sub-voice*/ses-*/func/*pataka*events.tsv
# df = pd.read_table(test[0])
# name = str(Path(test[0]).stem)
# name.split('_')[1].split['-'][1]
#     for f in all_events:
#         #df = pd.read_csv(f,sep='\t')
#         df = pd.read_table(f)
#         if df.shape[0]>0:
#             name = str(Path(f).stem)
#             subj = name.split('_')[0]
#             ses = name.split('_')[1]
#             task = name.split('task_')[2]
#             run = name.split('_0')[3]
        
#             has_pop_events.append(f)
            #df['subj'] = [name.split('_')[0]] * df.shape[0]
            #df['ses'] = [name.split('_')[1]] * df.shape[0]
            #df['task'] = [name.split('_')[2]] * df.shape[0]
            #df['run'] = [name.split('_')[3]] * df.shape[0]
            #events_w_metadata_all.append(df)

    #only keep ones that aren't empty to test if same ses/run are the same    
    #populated_events = [c for c in events_w_metadata_all if c.shape[0]>0]
